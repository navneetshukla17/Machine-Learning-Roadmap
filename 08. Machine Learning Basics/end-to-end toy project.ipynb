# %%
# to ignore warnings
import warnings
warnings.filterwarnings(action='ignore')

# for data manipulation & analysis
import pandas as pd
import numpy as np

# for data visualization
import matplotlib.pyplot as plt

# for traing and testing the model
from sklearn.model_selection import train_test_split

# for scaling the data
from sklearn.preprocessing import StandardScaler

# for performing logistic regression on the dataset
from sklearn.linear_model import LogisticRegression

# for testing models accuracy 
from sklearn.metrics import accuracy_score

# for plotting decision boundry
from mlxtend.plotting import plot_decision_regions

# %%
df.shape

# %%
df.head()

# %% [markdown]
# Remove col: 'Unnamed: 0'

# %%
df = df.iloc[:,1:]

# %%
df.head()

# %%
df.isnull().sum()

# %% [markdown]
# No Missing Values in the Dataset!

# %%
df.info()

# %% [markdown]
# ### Data Visualization

# %%
# scatter plot on the dataset
plt.scatter(df['cgpa'], df['iq'], c=df['placement'])
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.show()

# %%
# Independent variable
X = df.iloc[:,:2]
y = df['placement']

# %% [markdown]
# ### Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
X_train

# %%
y_train

# %%
X_test

# %%
y_test

# %% [markdown]
# ### Scaling the values

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train

# %%
X_test = scaler.transform(X_test)

# %%
X_test

# %% [markdown]
# ### Model Traning

# %%
# creating object of logistic regression classifier
classifier = LogisticRegression()

# %%
classifier.fit(X_train, y_train)

# %% [markdown]
# ### Model Testing / Evaluation

# %%
# result predicted by our machine learning model...
y_pred = classifier.predict(X_test)

# %%
# actual results
y_test

# %%
print(accuracy_score(y_test, y_pred)*100,'% Accurate')

# %% [markdown]
# ### Plotting decision boundries

# %%
plot_decision_regions(X_train, y_train.values, clf=classifier, legend=2)
plt.show()
