# %%
import numpy as np
from sklearn import linear_model
import time

# %%
n_samples, n_features = 1, 500

# %%
X = np.random.randn(n_samples, n_features)
y = np.random.randn(n_samples)

# %%
classifier = linear_model.SGDClassifier()

# %%
start_time = time.time()
classifier.partial_fit(X, y)
elapsed_time = time.time() - start_time
print(elapsed_time)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 start_time = time.time()
# ----> 2 classifier.partial_fit(X, y)
#       3 elapsed_time = time.time() - start_time
#       4 print(elapsed_time)
#
# File /usr/lib/python3/dist-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File /usr/lib/python3/dist-packages/sklearn/linear_model/_stochastic_gradient.py:872, in BaseSGDClassifier.partial_fit(self, X, y, classes, sample_weight)
#     859     if self.class_weight == "balanced":
#     860         raise ValueError(
#     861             "class_weight '{0}' is not supported for "
#     862             "partial_fit. In order to use 'balanced' weights,"
#    (...)
#     869             "parameter.".format(self.class_weight)
#     870         )
# --> 872 return self._partial_fit(
#     873     X,
#     874     y,
#     875     alpha=self.alpha,
#     876     C=1.0,
#     877     loss=self.loss,
#     878     learning_rate=self.learning_rate,
#     879     max_iter=1,
#     880     classes=classes,
#     881     sample_weight=sample_weight,
#     882     coef_init=None,
#     883     intercept_init=None,
#     884 )
#
# File /usr/lib/python3/dist-packages/sklearn/linear_model/_stochastic_gradient.py:608, in BaseSGDClassifier._partial_fit(self, X, y, alpha, C, loss, learning_rate, max_iter, classes, sample_weight, coef_init, intercept_init)
#     596 X, y = self._validate_data(
#     597     X,
#     598     y,
#    (...)
#     603     reset=first_call,
#     604 )
#     606 n_samples, n_features = X.shape
# --> 608 _check_partial_fit_first_call(self, classes)
#     610 n_classes = self.classes_.shape[0]
#     612 # Allocate datastructures from input arguments
#
# File /usr/lib/python3/dist-packages/sklearn/utils/multiclass.py:417, in _check_partial_fit_first_call(clf, classes)
#     403 """Private helper function for factorizing common classes param logic.
#     404
#     405 Estimators that implement the ``partial_fit`` API need to be provided with
#    (...)
#     414
#     415 """
#     416 if getattr(clf, "classes_", None) is None and classes is None:
# --> 417     raise ValueError("classes must be passed on the first call to partial_fit.")
#     419 elif classes is not None:
#     420     if getattr(clf, "classes_", None) is not None:
#
# ValueError: classes must be passed on the first call to partial_fit.
