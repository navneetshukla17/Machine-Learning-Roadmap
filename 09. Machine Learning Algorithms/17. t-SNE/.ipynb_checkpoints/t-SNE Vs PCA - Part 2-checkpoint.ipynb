# %%
from sklearn.datasets import make_classification
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
# dummy dataset
X, y = make_classification(
    n_samples=15000,
    n_features=6,
    n_classes=3,
    n_informative=2,
    random_state=42,
    n_clusters_per_class=1
)

# %%
fig = px.scatter_3d(
    x=X[:,0],
    y=X[:,1],
    z=X[:,2],
    color=y,
    opacity=0.7
)
fig.show()

# %% [markdown]
# ### PCA Visualization

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

fig = px.scatter(
    x=X_pca[:,0],
    y=X_pca[:,1],
    color=y
)
fig.update_layout(
    title='PCA visualization on Dummy Dataset',
    xaxis_title='First Principal Components',
    yaxis_title='Second Principal Components'
)
fig.show()

# %% [markdown]
# ### t-SNE Visualization

# %%
tsne = TSNE(n_components=2,
           perplexity=30,
           max_iter=1000,
           random_state=42)

X_tsne = tsne.fit_transform(X)
tsne.kl_divergence_

fig = px.scatter(
    x=X_tsne[:,0],
    y=X_tsne[:,1],
    color=y
)
fig.update_layout(
    title='t-SNE visualization on Dummy Dataset',
    xaxis_title='First t-SNE',
    yaxis_title='Second t-SNE'
)
fig.show()
