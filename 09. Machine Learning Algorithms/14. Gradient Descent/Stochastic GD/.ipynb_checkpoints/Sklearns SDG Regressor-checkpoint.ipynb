# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = load_diabetes()

# %%
X = data.data
y = data.target

# %%
df = pd.DataFrame(X, columns=data.feature_names)
df['target'] = y

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# 0   -0.002592  0.019907 -0.017646   151.0
# 1   -0.039493 -0.068332 -0.092204    75.0
# 2   -0.002592  0.002861 -0.025930   141.0
# 3    0.034309  0.022688 -0.009362   206.0
# 4   -0.002592 -0.031988 -0.046641   135.0
# ..        ...       ...       ...     ...
# 437 -0.002592  0.031193  0.007207   178.0
# 438  0.034309 -0.018114  0.044485   104.0
# 439 -0.011080 -0.046883  0.015491   132.0
# 440  0.026560  0.044529 -0.025930   220.0
# 441 -0.039493 -0.004222  0.003064    57.0
#
# [442 rows x 11 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
lr_reg = LinearRegression()
lr_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr_reg.coef_)
print(lr_reg.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# 151.88331005254165

# %%
y_pred = lr_reg.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.439933866156897

# %%
from sklearn.linear_model import SGDRegressor

# %%
sk_sgd = SGDRegressor(max_iter=100, learning_rate='constant', eta0=0.01)
sk_sgd.fit(X_train, y_train)
sk_ypred = sk_sgd.predict(X_test)

# %%
print(sk_sgd.coef_)
print(sk_sgd.intercept_)
# Out:
# [  56.69108842  -62.19459584  341.28411679  242.2680504    20.2931673
#   -23.88970408 -170.52779112  128.84926557  310.94856967  128.03067403]
# [149.49057016]

# %%
r2_score(y_test, sk_ypred)
# Out:
# 0.42947681245436264
