# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

# %%
X, y = make_regression(n_samples=100,
                n_features=1,
                n_informative=1,
                n_targets=1,
                noise=20
)

# %%
plt.scatter(X, y)
plt.show()

# %%
lr_reg = LinearRegression()
lr_reg.fit(X, y)
y_pred = lr_reg.predict(X)
print(f'Slope(m):{lr_reg.coef_}')
print(f'Intercept(b):{lr_reg.intercept_}')

plt.scatter(X,y)
plt.plot(X, y_pred, color='red')
plt.title('Results of LinearRegression')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
# Out:
# Slope(m):[27.57498799]
# Intercept(b):0.6163702864128098

# %%
m = 27.57

# %%
class GDRegressor:
    def __init__(self, learning_rate, epochs):
        self.m = 27.57
        self.b = -120
        self.lr = learning_rate
        self.epochs = epochs

    def fit(self, X, y):
        # calculate the b using GD
        for i in range(self.epochs):
            loss_slope = -2 * np.sum(y - self.m*X.ravel() - self.b)
            self.b = self.b - (self.lr * loss_slope)
        
        print(self.b)

# %%
gd = GDRegressor(0.001, 57)
gd.fit(X, y)
# Out:
# 0.6163880637855577
