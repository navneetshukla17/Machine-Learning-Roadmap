# %%
import numpy as np
from sklearn.datasets import load_diabetes

# %%
X, y = load_diabetes(return_X_y=True)

# %%
X.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %% [markdown]
# ### Using Sklearn's Linear Regression class

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
X_train.shape
# Out:
# (353, 10)

# %%
X_test.shape
# Out:
# (89, 10)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4399338661568969

# %%
lr.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
lr.intercept_
# Out:
# 151.88331005254167

# %% [markdown]
# ### Making our own Linear Regression Class

# %%
class MultipleLinearRegression:
    
    def __init__(self):
        
        self.coef_ = None
        self.intercept_ = None
    
    def fit(self, X, y):
        
        X_transpose = X.T
        X = np.insert(X, 0, 1, axis=1)
        
        betas = np.linalg.inv(X_transpose @ X) @ X_transpose @ y
        self.intercept_ = betas[0]
        self.coef_ = betas[1:]
    
    def predict(self, X):
        
        return np.dot(X, self.coef_) + self.intercept_

# %%
LR = MultipleLinearRegression()

# %%
LR.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 LR.fit(X_train, y_train)
#
# Cell In[29], line 16, in MultipleLinearRegression.fit(self, X, y)
#      13 X_transpose = X.T
#      14 X = np.insert(X, 0, 1, axis=1)
# ---> 16 betas = np.linalg.inv(X_transpose @ X) @ X_transpose @ y
#      17 self.intercept_ = betas[0]
#      18 self.coef_ = betas[1:]
#
# File /usr/lib/python3/dist-packages/numpy/linalg/linalg.py:556, in inv(a)
#     554 a, wrap = _makearray(a)
#     555 _assert_stacked_2d(a)
# --> 556 _assert_stacked_square(a)
#     557 t, result_t = _commonType(a)
#     559 signature = 'D->D' if isComplexType(t) else 'd->d'
#
# File /usr/lib/python3/dist-packages/numpy/linalg/linalg.py:213, in _assert_stacked_square(*arrays)
#     211 m, n = a.shape[-2:]
#     212 if m != n:
# --> 213     raise LinAlgError('Last 2 dimensions of the array must be square')
#
# LinAlgError: Last 2 dimensions of the array must be square
