# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
class MyLrOptimised:
    
    def __init__(self):
        self.m = None # slope of the line (theta)
        self.b = None # y-intercept / offset 
    
    def fit(self, X, y):
        
        X = np.array(X)
        y = np.array(y)
        
        X_mean = np.mean(X)
        y_mean = np.mean(y)
        
        numerator = np.sum((X - X_mean) * (y - y_mean))
        denominator = np.sum((X - X_mean) ** 2)
        self.m = numerator / denominator
        self.b = y_mean - self.m * X_mean
    
    def predict(self, X):
        
        X = np.array(X)
        # y = mx+b
        return self.m * X + self.b
    
    def score(self, X, y):
        
        X = np.array(X)
        y = np.array(y)
        y_predict = self.predict(X)
        residual = np.sum((y - y_predict) ** 2)
        total = np.sum((y - np.mean(y)) ** 2)
        
        score = 1 - (residual / total)
        return score

# %%
df = pd.read_csv('cgpa_package_data.csv')

# %%
df.head()
# Out:
#        CGPA    Package
# 0  6.872701   9.503310
# 1  9.753572  13.141693
# 2  8.659970  12.586373
# 3  7.993292  11.005014
# 4  5.780093   9.492429

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['CGPA'], df['Package'])
plt.xlabel('CGPA')
plt.ylabel('Package (LPA)')
plt.show()

# %%
X = df.iloc[:,0:1].values
y = df.iloc[:,1:2].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
lr = MyLrOptimised()

# %%
lr.fit(X_train, y_train)

# %%
lr.predict(X_test)
# Out:
# array([[11.88691195],
#        [ 9.00769187],
#        [10.4839989 ],
#        ...,
#        [ 8.85042991],
#        [13.00482598],
#        [13.13861744]])

# %%
lr.score(X_test, y_test)
# Out:
# 0.9210335912597543

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = Lnie
