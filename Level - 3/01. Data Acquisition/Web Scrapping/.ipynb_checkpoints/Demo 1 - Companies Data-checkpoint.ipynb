# %%
import pandas as pd
from bs4 import BeautifulSoup
import time
import requests
import re

def scrape_data():
    all_data = []

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                      "AppleWebKit/537.36 (KHTML, like Gecko) "
                      "Chrome/124.0.0.0 Safari/537.36"
    }

    for page in range(1, 501):
        url1 = f'https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav&page={page}'
        print(f"Scraping page {page}...")

        webpage = requests.get(url1, headers=headers)
        soup = BeautifulSoup(response.text, "lxml")

        # Company Name
        company_tag = soup.find_all('h2', class_='companyCardWrapper__companyName')
        company_names = [tag.text.strip() for tag in company_tag]
    
        # Company Ratings
        rating_tag = soup.find_all(class_='rating_text rating_text--md')
        ratings = [tag.text.strip() for tag in rating_tag]
    
        # Company Reviews
        review_tag = soup.find_all(class_='companyCardWrapper__companyRatingCount')
        reviews = [tag.text.strip() for tag in review_tag]
    
        # Company Type
        ctype_tag = soup.find_all(class_='companyCardWrapper__interLinking')
        ctype = [tag.text.split('|')[0].strip() for tag in ctype_tag]

        for i in range(len(company_names)):
            data = {
                'Name': company_names[i] if i < len(company_names) else None,
                'Ratings': ratings[i] if i < len(ratings) else None,
                'Reviews': reviews[i] if i < len(reviews) else None,
                'Category': ctype[i] if i < len(ctype) else None
            }
            all_data.append(data)
            
        # Small delay to avoid getting blocked
        time.sleep(1.5)

    df = pd.DataFrame(all_data)
    df.to_csv('ambitionbox_companies_data.csv', index=False, encoding='utf-8-sig')
    print("✅ Data scraping complete! Saved to 'ambitionbox_companies.csv'")

# Run it
scrape_data()
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# Scraping page 6...
# Scraping page 7...
# Scraping page 8...
# Scraping page 9...
# Scraping page 10...
# Scraping page 11...
# Scraping page 12...
# Scraping page 13...
# Scraping page 14...
# Scraping page 15...
# Scraping page 16...
# Scraping page 17...
# Scraping page 18...
# Scraping page 19...
# Scraping page 20...
# Scraping page 21...
# Scraping page 22...
# Scraping page 23...
# Scraping page 24...
# Scraping page 25...
# Scraping page 26...
# Scraping page 27...
# Scraping page 28...
# Scraping page 29...
# Scraping page 30...
# Scraping page 31...
# Scraping page 32...
# Scraping page 33...
# Scraping page 34...
# Scraping page 35...
# Scraping page 36...
# Scraping page 37...
# Scraping page 38...
# Scraping page 39...
# Scraping page 40...
# Scraping page 41...
# Scraping page 42...
# Scraping page 43...
# Scraping page 44...
# Scraping page 45...
# ...

# %%
df = pd.read_csv('ambitionbox_companies_data.csv')
